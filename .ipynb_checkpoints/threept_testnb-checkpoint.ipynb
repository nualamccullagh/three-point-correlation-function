# %%
import numpy as N
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# //anaconda/lib/python2.7/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')

# %%
plt.style.use('nuala')

# %%
import threeptfn as T

# %%
T.setup('pk_indra7313.txt')
# Out:
# threeptfn.py:219: RuntimeWarning: divide by zero encountered in divide
#   ans=S.jn(n+0.5, z)*N.sqrt(N.pi/(2*z))
# threeptfn.py:219: RuntimeWarning: invalid value encountered in multiply
#   ans=S.jn(n+0.5, z)*N.sqrt(N.pi/(2*z))

# %%
import test_script as tt

# %%
tt.plot_realspace(1.0, 0.0, 0.0)
# Out:
# 81
# 81

# %%
# arguments are: b1, b2, bs, f
tt.make_plots(1.0, 0.0, 0.0, 0.0)

# %%
tt.make_plots(2.0, 2.0, 0.0, 0.5)

# %%
tt.make_plots(0.8, -0.16, 0.0, 0.46)

# %%
reload(tt)
reload(T)
# Out:
# <module 'threeptfn' from 'threeptfn.py'>

# %%
b1=3.0
b2=b1*(b1-1.0)
bs=4./7.*(1-b1)
tt.make_plots(b1, b2, bs, 1.0)

# %%
tt.plot_realspace(4.0, 0.0, 0.0)
# Out:
# 81
# 81

# %%
reload(tt)
# Out:
# <module 'test_script' from 'test_script.py'>

# %%
reload(T)
# Out:
# <module 'threeptfn' from 'threeptfn.py'>
