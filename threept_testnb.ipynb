# %%
import numpy as N
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.style.use('nuala')

# %%
import threeptfn as T

# %%
T.setup('pk_indra7313.txt')
# Out:
# threeptfn.py:221: RuntimeWarning: divide by zero encountered in divide
# threeptfn.py:221: RuntimeWarning: invalid value encountered in multiply

# %%
import test_script as tt

# %%
tt.plot_realspace(1.0, 0.0, 0.0)

# %%
# arguments are: b1, b2, bs, f
tt.make_plots(1.0, 0.0, 0.0, 0.0)

# %%
tt.make_plots(2.0, 2.0, 0.0, 0.5)

# %%
tt.make_plots(0.8, -0.16, 0.0, 0.46)
